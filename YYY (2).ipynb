# %%
import pandas as pd
import seaborn as sb
import matplotlib as plt
# %matplotlib inline
import numpy as np
import warnings

warnings.simplefilter("ignore")

# %%
dia=pd.read_csv("Diabetes.csv")
dia.head()
dia['output']="NAN"
dia.head()
dia.shape
# Out:
# (768, 10)

# %%
for i in range(len(dia.index)):
    if dia['Glucose'][i]>125:
        dia['output'][i]="diabetic"
    elif 100<=dia['Glucose'][i]>=125:
        dia['output'][i]="prediabetic"
    else: 
        dia['output'][i]="normal"

# %%
# or else we can us applu function
dia.head()
count=(dia['Insulin']==0).sum()
print(count)
# Out:
# 374

# %%
dia1=dia.copy()

# %%
dia1['output']=dia1['Glucose'].apply(lambda x:'diabetes' if x>125 else 'prediabetic' if 100<=x<=125 else 'normal')

# %%
dia1.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome    output
# 0                     0.627   50        1  diabetes
# 1                     0.351   31        0    normal
# 2                     0.672   32        1  diabetes
# 3                     0.167   21        0    normal
# 4                     2.288   33        1  diabetes

# %%
dia['output']=dia['output'].replace('normal',0)
dia['output']=dia['output'].replace('prediabetic',1)
dia['output']=dia['output'].replace('diabetic',2)

# %%
dia.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  output
# 0                     0.627   50        1       2
# 1                     0.351   31        0       0
# 2                     0.672   32        1       2
# 3                     0.167   21        0       0
# 4                     2.288   33        1       2

# %%
#or else we can use dictinaries
dia1.replace({'output':{'normal':0,'prediabetic':1,'diabetes':2,}})
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# 12            10      139             80              0        0  27.1
# 13             1      189             60             23      846  30.1
# 14             5      166             72             19      175  25.8
# 15             7      100              0              0        0  30.0
# 16             0      118             84             47      230  45.8
# 17             7      107             74              0        0  29.6
# 18             1      103             30             38       83  43.3
# 19             1      115             70             30       96  34.6
# 20             3      126             88             41      235  39.3
# 21             8       99             84              0        0  35.4
# 22             7      196             90              0        0  39.8
# 23             9      119             80             35        0  29.0
# 24            11      143             94             33      146  36.6
# 25            10      125             70             26      115  31.1
# 26             7      147             76              0        0  39.4
# 27             1       97             66             15      140  23.2
# 28            13      145             82             19      110  22.2
# 29             5      117             92              0        0  34.1
# ..           ...      ...            ...            ...      ...   ...
# 738            2       99             60             17      160  36.6
# 739            1      102             74              0        0  39.5
# 740           11      120             80             37      150  42.3
# 741            3      102             44             20       94  30.8
# 742            1      109             58             18      116  28.5
# 743            9      140             94              0        0  32.7
# 744           13      153             88             37      140  40.6
# 745           12      100             84             33      105  30.0
# 746            1      147             94             41        0  49.3
# 747            1       81             74             41       57  46.3
# 748            3      187             70             22      200  36.4
# 749            6      162             62              0        0  24.3
# 750            4      136             70              0        0  31.2
# 751            1      121             78             39       74  39.0
# 752            3      108             62             24        0  26.0
# 753            0      181             88             44      510  43.3
# 754            8      154             78             32        0  32.4
# 755            1      128             88             39      110  36.5
# 756            7      137             90             41        0  32.0
# 757            0      123             72              0        0  36.3
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  output
# 0                       0.627   50        1       2
# 1                       0.351   31        0       0
# 2                       0.672   32        1       2
# 3                       0.167   21        0       0
# 4                       2.288   33        1       2
# 5                       0.201   30        0       1
# 6                       0.248   26        1       0
# 7                       0.134   29        0       1
# 8                       0.158   53        1       2
# 9                       0.232   54        1       1
# 10                      0.191   30        0       1
# 11                      0.537   34        1       2
# 12                      1.441   57        0       2
# 13                      0.398   59        1       2
# 14                      0.587   51        1       2
# 15                      0.484   32        1       1
# 16                      0.551   31        1       1
# 17                      0.254   31        1       1
# 18                      0.183   33        0       1
# 19                      0.529   32        1       1
# 20                      0.704   27        0       2
# 21                      0.388   50        0       0
# 22                      0.451   41        1       2
# 23                      0.263   29        1       1
# 24                      0.254   51        1       2
# 25                      0.205   41        1       1
# 26                      0.257   43        1       2
# 27                      0.487   22        0       0
# 28                      0.245   57        0       2
# 29                      0.337   38        0       1
# ..                        ...  ...      ...     ...
# 738                     0.453   21        0       0
# 739                     0.293   42        1       1
# 740                     0.785   48        1       1
# 741                     0.400   26        0       1
# 742                     0.219   22        0       1
# 743                     0.734   45        1       2
# 744                     1.174   39        0       2
# 745                     0.488   46        0       1
# 746                     0.358   27        1       2
# 747                     1.096   32        0       0
# 748                     0.408   36        1       2
# 749                     0.178   50        1       2
# 750                     1.182   22        1       2
# 751                     0.261   28        0       1
# 752                     0.223   25        0       1
# 753                     0.222   26        1       2
# 754                     0.443   45        1       2
# 755                     1.057   37        1       2
# 756                     0.391   39        0       2
# 757                     0.258   52        1       1
# 758                     0.197   26        0       1
# 759                     0.278   66        1       2
# 760                     0.766   22        0       0
# 761                     0.403   43        1       2
# 762                     0.142   33        0       0
# 763                     0.171   63        0       1
# 764                     0.340   27        0       1
# 765                     0.245   30        0       1
# 766                     0.349   47        1       2
# 767                     0.315   23        0       0
#
# [768 rows x 10 columns]

# %%
dia['Glucose']=dia[ 'Glucose'].replace(0,np.NAN)
dia.dropna(inplace=True)

# %%
dia.shape
# Out:
# (763, 10)

# %%
dia=dia[['Glucose','Insulin','output']]

# %%
dia.to_csv('diabetes22.csv',index=False)

# %%
dia2=pd.read_csv("Diabetes.csv")
dia2.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data=dia2[['Glucose','Insulin','Outcome']]
data.shape
# Out:
# (768, 3)

# %%
data['Glucose']=data[ 'Glucose'].replace(0,np.NAN)
data.dropna(inplace=True)

data.to_csv("diabetis22.csv",index=False)

# %%
data.head()
# Out:
#    Glucose  Insulin  Outcome
# 0    148.0        0        1
# 1     85.0        0        0
# 2    183.0        0        1
# 3     89.0       94        0
# 4    137.0      168        1

# %%
fr=data[data['Insulin']==0]
fr.to_csv('predict.csv',index=False)
sr=fr.iloc[:,fr.columns!='Insulin']
sr.head()
# Out:
#    Glucose  Outcome
# 0    148.0        1
# 1     85.0        0
# 2    183.0        1
# 5    116.0        0
# 7    115.0        0

# %%
kr=data[data['Insulin']!=0]
kr.head()
# Out:
#     Glucose  Insulin  Outcome
# 3      89.0       94        0
# 4     137.0      168        1
# 6      78.0       88        1
# 8     197.0      543        1
# 13    189.0      846        1

# %%
x=kr.loc[:,kr.columns!='Insulin']
y=kr.drop(['Glucose','Outcome'],axis=1)
y.shape
# Out:
# (393, 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix,accuracy_score,r2_score,mean_squared_error,mean_absolute_error,classification_report

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=123)

# %%
ref=LinearRegression()
model=ref.fit(x_train,y_train)

y_pred=ref.predict(x_test)
print(y_pred,y_test)
print (x_train.shape)
print (x_test.shape)
print (y_train.shape)
print (y_test.shape)
# Out:
# [[188.94602561]
#  [167.8478944 ]
#  [191.29026241]
#  [210.85417935]
#  [231.14228802]
#  [174.8806048 ]
#  [174.8806048 ]
#  [295.24670418]
#  [104.55350077]
#  [106.89773757]
#  [158.47094719]
#  [ 74.07842236]
#  [167.8478944 ]
#  [186.60178881]
#  [196.78875854]
#  [167.8478944 ]
#  [227.26383695]
#  [135.83860172]
#  [238.98502096]
#  [166.31368013]
#  [240.51923523]
#  [104.55350077]
#  [160.815184  ]
#  [ 60.82302409]
#  [213.19841615]
#  [128.80589132]
#  [ 45.94758075]
#  [314.00059859]
#  [ 78.76689596]
#  [104.55350077]
#  [ 69.38994876]
#  [170.1921312 ]
#  [106.89773757]
#  [127.99586878]
#  [109.24197437]
#  [281.18128338]
#  [215.54265295]
#  [ 92.83231677]
#  [ 95.17655357]
#  [106.89773757]
#  [278.83704658]
#  [311.65636179]
#  [149.09399999]
#  [233.48652482]
#  [224.10957762]
#  [212.38839362]
#  [120.96315838]
#  [146.74976319]
#  [139.71705279]
#  [250.70620496]
#  [113.93044798]
#  [135.02857918]
#  [117.08470731]
#  [177.2248416 ]
#  [170.1921312 ]
#  [207.69992001]
#  [ 38.91487035]
#  [ 67.04571196]
#  [ 78.76689596]
#  [144.40552639]
#  [106.89773757]
#  [210.04415681]
#  [107.70776011]
#  [ 99.86502717]
#  [ 78.76689596]
#  [113.93044798]
#  [151.43823679]
#  [ 67.04571196]
#  [158.47094719]
#  [ 76.42265916]
#  [332.754493  ]
#  [ 81.11113276]
#  [187.41181134]
#  [199.13299534]
#  [ 52.98029115]
#  [196.78875854]
#  [111.58621118]
#  [ 45.94758075]
#  [201.47723214]]      Insulin
# 428      145
# 478       75
# 285      135
# 301      135
# 744      140
# 73       270
# 519      326
# 445       14
# 514       86
# 639       46
# 374      158
# 532       65
# 20       235
# 459       60
# 414      167
# 345      108
# 424      210
# 214      175
# 152      155
# 25       115
# 325      168
# 365       83
# 652       77
# 659       70
# 663      130
# 198       99
# 466       36
# 595      185
# 358       54
# 119       51
# ..       ...
# 306      132
# 50        82
# 665      132
# 448       64
# 507      170
# 538      210
# 413       61
# 97        76
# 108       18
# 32        54
# 393       87
# 446       70
# 95       228
# 70        90
# 526       82
# 553       44
# 644      152
# 575       63
# 490       66
# 530      106
# 377       75
# 359      249
# 112       37
# 171      130
# 189      160
# 534       56
# 614      144
# 741       94
# 234       45
# 375      325
#
# [79 rows x 1 columns]
# (314, 2)
# (79, 2)
# (314, 1)
# (79, 1)

# %%
model.score(x_train,y_train)
# Out:
# 0.3465317922908908

# %%
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.19862033282486058
# 6212.247926662155

# %%
newdf=pd.DataFrame([[144,2]])
prediction=ref.predict(newdf)
print(prediction.astype(int))
# Out:
# [[211]]

# %%
insulin=ref.predict(sr)
##print(insulin)

# %%
r=pd.read_csv('diabetes22.csv')
r
# Out:
#      Glucose  Insulin  output
# 0      148.0        0       2
# 1       85.0        0       0
# 2      183.0        0       2
# 3       89.0       94       0
# 4      137.0      168       2
# 5      116.0        0       0
# 6       78.0       88       0
# 7      115.0        0       0
# 8      197.0      543       2
# 9      125.0        0       1
# 10     110.0        0       0
# 11     168.0        0       2
# 12     139.0        0       2
# 13     189.0      846       2
# 14     166.0      175       2
# 15     100.0        0       0
# 16     118.0      230       0
# 17     107.0        0       0
# 18     103.0       83       0
# 19     115.0       96       0
# 20     126.0      235       2
# 21      99.0        0       0
# 22     196.0        0       2
# 23     119.0        0       0
# 24     143.0      146       2
# 25     125.0      115       1
# 26     147.0        0       2
# 27      97.0      140       0
# 28     145.0      110       2
# 29     117.0        0       0
# ..       ...      ...     ...
# 733     99.0      160       0
# 734    102.0        0       0
# 735    120.0      150       0
# 736    102.0       94       0
# 737    109.0      116       0
# 738    140.0        0       2
# 739    153.0      140       2
# 740    100.0      105       0
# 741    147.0        0       2
# 742     81.0       57       0
# 743    187.0      200       2
# 744    162.0        0       2
# 745    136.0        0       2
# 746    121.0       74       0
# 747    108.0        0       0
# 748    181.0      510       2
# 749    154.0        0       2
# 750    128.0      110       2
# 751    137.0        0       2
# 752    123.0        0       0
# 753    106.0        0       0
# 754    190.0        0       2
# 755     88.0       16       0
# 756    170.0        0       2
# 757     89.0        0       0
# 758    101.0      180       0
# 759    122.0        0       0
# 760    121.0      112       0
# 761    126.0        0       2
# 762     93.0        0       0
#
# [763 rows x 3 columns]

# %%
l=r[r['Insulin']==0]
l
# Out:
#      Glucose  Insulin  output
# 0      148.0        0       2
# 1       85.0        0       0
# 2      183.0        0       2
# 5      116.0        0       0
# 7      115.0        0       0
# 9      125.0        0       1
# 10     110.0        0       0
# 11     168.0        0       2
# 12     139.0        0       2
# 15     100.0        0       0
# 17     107.0        0       0
# 21      99.0        0       0
# 22     196.0        0       2
# 23     119.0        0       0
# 26     147.0        0       2
# 29     117.0        0       0
# 30     109.0        0       0
# 33      92.0        0       0
# 34     122.0        0       0
# 36     138.0        0       2
# 37     102.0        0       0
# 38      90.0        0       0
# 41     133.0        0       2
# 42     106.0        0       0
# 44     159.0        0       2
# 45     180.0        0       2
# 46     146.0        0       2
# 47      71.0        0       0
# 48     103.0        0       0
# 49     105.0        0       0
# ..       ...      ...     ...
# 707    129.0        0       2
# 709    102.0        0       0
# 712     94.0        0       0
# 714     97.0        0       0
# 715     83.0        0       0
# 719    111.0        0       0
# 720    112.0        0       0
# 722    141.0        0       2
# 723    175.0        0       2
# 724     92.0        0       0
# 726    120.0        0       0
# 729    105.0        0       0
# 730     95.0        0       0
# 732     65.0        0       0
# 734    102.0        0       0
# 738    140.0        0       2
# 741    147.0        0       2
# 744    162.0        0       2
# 745    136.0        0       2
# 747    108.0        0       0
# 749    154.0        0       2
# 751    137.0        0       2
# 752    123.0        0       0
# 753    106.0        0       0
# 754    190.0        0       2
# 756    170.0        0       2
# 757     89.0        0       0
# 759    122.0        0       0
# 761    126.0        0       2
# 762     93.0        0       0
#
# [370 rows x 3 columns]

# %%
j=0
for i in range(len(r.index)):
    if r['Insulin'][i]==0:
        r['Insulin'][i]=insulin[j]
        j=j+1

# %%
r.to_csv("finaldata.csv",index=False)

# %%
##classification

# %%
fina=pd.read_csv("finaldata.csv")

fina.shape
dia.shape

dia2['Glucose']=dia2[ 'Glucose'].replace(0,np.NAN)
dia2.dropna(inplace=True)
rat=pd.concat([fina,dia2],axis=1)
rat
##sb.heatmap(dia2.corr(),annot=True)
# Out:
#      Glucose  Insulin  output  Pregnancies  Glucose  BloodPressure  \
# 0      148.0    220.0     2.0          6.0    148.0           72.0
# 758            0.0      0.0  37.5                     0.197  26.0      0.0
# 759            0.0      0.0  35.5                     0.278  66.0      1.0
# 760           26.0     16.0  28.4                     0.766  22.0      0.0
# 761           31.0      0.0  44.0                     0.403  43.0      1.0
# 762            0.0      0.0  22.5                     0.142  33.0      0.0
# 763           48.0    180.0  32.9                     0.171  63.0      0.0
# 764           27.0      0.0  36.8                     0.340  27.0      0.0
# 765           23.0    112.0  26.2                     0.245  30.0      0.0
# 766            0.0      0.0  30.1                     0.349  47.0      1.0
# 767           31.0      0.0  30.4                     0.315  23.0      0.0
#
# [768 rows x 12 columns]

# %%
X=fina.loc[:,fina.columns!='output']
Y=fina['output']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=123)

# %%
from sklearn import preprocessing
scaler = preprocessing.StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

modal = KNeighborsClassifier()
modal.fit(X_train_scaled,Y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
Y_pred=modal.predict(X_test_scaled)
##print(Y_test,Y_pred)


X_train_scaled.shape
# Out:
# (610, 2)

# %%
accuracy_score(Y_test,Y_pred)*100
# Out:
# 96.73202614379085

# %%
sb.heatmap(confusion_matrix(Y_test,Y_pred),annot=True)

# %%
from sklearn.linear_model import LogisticRegression
classifier7 = LogisticRegression()
classifier7.fit(X_train_scaled,Y_train)
Y_lopred=classifier7.predict(X_test_scaled)
##print(Y_test,Y_lopred)

# %%
sb.heatmap(confusion_matrix(Y_test,Y_lopred),annot=True)

# %%
classification_report(Y_test,Y_lopred)

accuracy_score(Y_test,Y_lopred)*100
# Out:
# 97.38562091503267

# %%
from sklearn.naive_bayes import GaussianNB

#Create a Gaussian Classifier
gausmodal = GaussianNB()

# Train the model using the training sets
gausmodal .fit(X_train_scaled,Y_train)

#Predict Output
Y_gaupred= gausmodal.predict(X_test_scaled)

# %%
sb.heatmap(confusion_matrix(Y_test,Y_gaupred),annot=True)

# %%
classification_report(Y_test,Y_gaupred)

accuracy_score(Y_test,Y_gaupred)*100
# Out:
# 94.77124183006535

# %%
sb.countplot(x='output',data=fina)

# %%
from sklearn.tree import DecisionTreeClassifier
clf_model = DecisionTreeClassifier(criterion="gini", random_state=42,max_depth=3, min_samples_leaf=5)   
clf_model.fit(X_train_scaled,Y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=5, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')

# %%
Y_de=clf_model.predict(X_test_scaled)

# %%
sb.heatmap(confusion_matrix(Y_test,Y_de),annot=True)

# %%
accuracy_score(Y_test,Y_de)*100
# Out:
# 100.0

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='linear')
svclassifier.fit(X_train_scaled, Y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
y__pred = svclassifier.predict(X_test_scaled)

# %%
sb.heatmap(confusion_matrix(Y_test,y__pred),annot=True)

# %%
print(accuracy_score(Y_test,y__pred)*100)
# Out:
# 97.38562091503267

# %%
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train_scaled,Y_train)

y_pred=clf.predict(X_test_scaled)

# %%
sb.heatmap(confusion_matrix(y_pred,Y_test),annot=True)

# %%
accuracy_score(Y_test,y_pred)*100
# Out:
# 100.0

# %%
import pickle as pk

# %%
#feature scaling
pk.dump(scaler,open('scaler.pkl','wb'))
#k - neighbour
pk.dump(modal,open('modal.pkl','wb'))
#logistic
pk.dump(classifier7,open('classifier7.pkl','wb'))
#gaussiannb
pk.dump(gausmodal,open('gausmodal.pkl','wb'))
#svm
pk.dump(svclassifier,open('svclassifier.pkl','wb'))

# %%
sc=pk.load(open('scaler.pkl','rb'))
lo=pk.load(open('modal.pkl','rb'))

# %%
pred=lo.predict(sc.transform(np.array([[101,100]])))
print(pred)
# Out:
# [0]
